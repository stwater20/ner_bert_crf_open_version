# %%
# %cd /content/drive/MyDrive/ner_bert_crf_open_version/
# Out:
# /content/drive/MyDrive/ner_bert_crf_open_version

# %%
# !pip install torch==1.12.1
# !pip install transformers==4.24.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.12.1
#   Downloading torch-1.12.1-cp39-cp39-manylinux1_x86_64.whl (776.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.4/776.4 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.12.1) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.12.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.12.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.12.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed torch-1.12.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.24.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 45.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (3.10.7)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.24.0) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.24.0) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.24.0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.24.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.24.0) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.24.0

# %%
# !python train.py
# Out:
# 2023-04-10 04:49:29.812276: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 04:49:30.718113: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ***** Running training *****
#   Num examples = 5251
#   Batch size = 16
#   Num steps = 16409
# Downloading (…)okenizer_config.json: 100% 29.0/29.0 [00:00<00:00, 4.45kB/s]
# Downloading (…)lve/main/config.json: 100% 570/570 [00:00<00:00, 81.1kB/s]
# Downloading (…)solve/main/vocab.txt: 100% 213k/213k [00:00<00:00, 624kB/s]
# Downloading (…)/main/tokenizer.json: 100% 436k/436k [00:00<00:00, 23.3MB/s]
# Downloading pytorch_model.bin: 100% 436M/436M [00:24<00:00, 17.5MB/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# --------------------------------------------------------------
# Epoch:0 completed, Total training's Loss: 3100161.685546875, Spend: 1.2961121360460917m
# /content/drive/MyDrive/ner_bert_crf_open_version/train.py:535: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   valid_predicted = torch.masked_select(predicted_label_seq_ids, predict_mask)
# /content/drive/MyDrive/ner_bert_crf_open_version/train.py:536: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   valid_label_ids = torch.masked_select(label_ids, predict_mask)
# Epoch:0, Acc:83.09, Precision: 40.26, Recall: 21.29, F1: 27.85 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:1 completed, Total training's Loss: 3068873.87109375, Spend: 1.3704846541086833m
# Epoch:1, Acc:86.96, Precision: 59.41, Recall: 55.82, F1: 57.55 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:2 completed, Total training's Loss: 3065751.5610351562, Spend: 1.3588943799336752m
# Epoch:2, Acc:88.11, Precision: 59.88, Recall: 71.85, F1: 65.32 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:3 completed, Total training's Loss: 3060513.4497070312, Spend: 1.3529385447502136m
# Epoch:3, Acc:89.22, Precision: 63.01, Recall: 76.68, F1: 69.18 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:4 completed, Total training's Loss: 3061525.728515625, Spend: 1.3551325678825379m
# Epoch:4, Acc:91.93, Precision: 75.80, Recall: 74.46, F1: 75.12 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:5 completed, Total training's Loss: 3054479.9189453125, Spend: 1.3571847279866536m
# Epoch:5, Acc:92.99, Precision: 75.88, Recall: 83.60, F1: 79.55 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:6 completed, Total training's Loss: 3048632.5190429688, Spend: 1.3574092070261636m
# Epoch:6, Acc:94.12, Precision: 81.45, Recall: 83.09, F1: 82.26 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:7 completed, Total training's Loss: 3046331.4248046875, Spend: 1.3676627635955811m
# Epoch:7, Acc:93.76, Precision: 78.00, Recall: 85.94, F1: 81.78 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:8 completed, Total training's Loss: 3036370.41015625, Spend: 1.3603152672449748m
# Epoch:8, Acc:93.45, Precision: 76.27, Recall: 86.94, F1: 81.25 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:9 completed, Total training's Loss: 3032716.1489257812, Spend: 1.364429247379303m
# Epoch:9, Acc:94.16, Precision: 79.24, Recall: 86.37, F1: 82.65 on Valid_set, Spend:0.055 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:10 completed, Total training's Loss: 3030547.826171875, Spend: 1.3684147993723552m
# Epoch:10, Acc:94.35, Precision: 80.98, Recall: 85.61, F1: 83.23 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:11 completed, Total training's Loss: 3025022.80859375, Spend: 1.3603530605634053m
# Epoch:11, Acc:94.30, Precision: 80.14, Recall: 86.37, F1: 83.13 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:12 completed, Total training's Loss: 3011251.5278320312, Spend: 1.360498555501302m
# Epoch:12, Acc:94.38, Precision: 80.19, Recall: 87.52, F1: 83.69 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:13 completed, Total training's Loss: 3007726.984375, Spend: 1.3606408516565958m
# Epoch:13, Acc:94.14, Precision: 81.69, Recall: 83.48, F1: 82.58 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:14 completed, Total training's Loss: 2998411.322265625, Spend: 1.343934917449951m
# Epoch:14, Acc:94.37, Precision: 81.16, Recall: 86.37, F1: 83.68 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:15 completed, Total training's Loss: 2996859.171875, Spend: 1.3566233277320863m
# Epoch:15, Acc:94.30, Precision: 79.53, Recall: 87.06, F1: 83.13 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:16 completed, Total training's Loss: 2990321.9262695312, Spend: 1.3738382856051128m
# Epoch:16, Acc:94.25, Precision: 81.64, Recall: 84.91, F1: 83.24 on Valid_set, Spend:0.055 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:17 completed, Total training's Loss: 2984838.2958984375, Spend: 1.3695219119389852m
# Epoch:17, Acc:94.45, Precision: 80.11, Recall: 86.94, F1: 83.38 on Valid_set, Spend:0.055 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:18 completed, Total training's Loss: 2976832.4658203125, Spend: 1.3518840471903484m
# Epoch:18, Acc:94.43, Precision: 80.77, Recall: 86.21, F1: 83.40 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:19 completed, Total training's Loss: 2969356.96484375, Spend: 1.345606768131256m
# Epoch:19, Acc:94.53, Precision: 80.67, Recall: 86.82, F1: 83.63 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:20 completed, Total training's Loss: 2957819.1259765625, Spend: 1.34957727988561m
# Epoch:20, Acc:94.25, Precision: 80.13, Recall: 86.70, F1: 83.28 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:21 completed, Total training's Loss: 2951050.2290039062, Spend: 1.3423540274302164m
# Epoch:21, Acc:94.50, Precision: 81.87, Recall: 85.55, F1: 83.66 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:22 completed, Total training's Loss: 2941424.146484375, Spend: 1.3435217062632243m
# Epoch:22, Acc:94.44, Precision: 80.87, Recall: 86.67, F1: 83.67 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:23 completed, Total training's Loss: 2934858.408203125, Spend: 1.3468392769495645m
# Epoch:23, Acc:94.71, Precision: 84.03, Recall: 84.85, F1: 84.44 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:24 completed, Total training's Loss: 2925969.1416015625, Spend: 1.3373863180478414m
# Epoch:24, Acc:94.48, Precision: 81.44, Recall: 86.64, F1: 83.96 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:25 completed, Total training's Loss: 2920841.06640625, Spend: 1.345541779200236m
# Epoch:25, Acc:94.42, Precision: 81.05, Recall: 86.24, F1: 83.57 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:26 completed, Total training's Loss: 2915762.697265625, Spend: 1.3421815236409504m
# Epoch:26, Acc:94.45, Precision: 80.66, Recall: 86.88, F1: 83.65 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:27 completed, Total training's Loss: 2908623.98828125, Spend: 1.3457457820574443m
# Epoch:27, Acc:94.61, Precision: 82.28, Recall: 85.30, F1: 83.76 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:28 completed, Total training's Loss: 2904578.9829101562, Spend: 1.3477109710375468m
# Epoch:28, Acc:94.67, Precision: 81.61, Recall: 86.37, F1: 83.92 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:29 completed, Total training's Loss: 2893578.0537109375, Spend: 1.344168245792389m
# Epoch:29, Acc:94.41, Precision: 80.82, Recall: 86.64, F1: 83.63 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:30 completed, Total training's Loss: 2891763.0205078125, Spend: 1.3365566412607828m
# Epoch:30, Acc:94.47, Precision: 81.01, Recall: 86.52, F1: 83.67 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:31 completed, Total training's Loss: 2885338.8251953125, Spend: 1.3410672346750896m
# Epoch:31, Acc:94.79, Precision: 81.61, Recall: 87.31, F1: 84.36 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:32 completed, Total training's Loss: 2883363.134765625, Spend: 1.3510899861653647m
# Epoch:32, Acc:94.53, Precision: 80.59, Recall: 86.97, F1: 83.66 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:33 completed, Total training's Loss: 2875827.0024414062, Spend: 1.3537014881769815m
# Epoch:33, Acc:94.49, Precision: 81.29, Recall: 85.91, F1: 83.54 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:34 completed, Total training's Loss: 2865004.9409179688, Spend: 1.3426082928975422m
# Epoch:34, Acc:94.66, Precision: 81.18, Recall: 86.85, F1: 83.92 on Valid_set, Spend:0.052 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:35 completed, Total training's Loss: 2867849.7998046875, Spend: 1.3421863476435343m
# Epoch:35, Acc:94.70, Precision: 81.61, Recall: 86.94, F1: 84.19 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:36 completed, Total training's Loss: 2858703.5234375, Spend: 1.3462202310562135m
# Epoch:36, Acc:94.77, Precision: 82.38, Recall: 86.73, F1: 84.50 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:37 completed, Total training's Loss: 2858687.6313476562, Spend: 1.3488975445429483m
# Epoch:37, Acc:94.78, Precision: 82.47, Recall: 86.73, F1: 84.55 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:38 completed, Total training's Loss: 2851846.2890625, Spend: 1.357277548313141m
# Epoch:38, Acc:94.73, Precision: 81.77, Recall: 86.79, F1: 84.21 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:39 completed, Total training's Loss: 2852502.2622070312, Spend: 1.3488534172375997m
# Epoch:39, Acc:94.43, Precision: 80.92, Recall: 86.40, F1: 83.57 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:40 completed, Total training's Loss: 2846383.9848632812, Spend: 1.3437132318814595m
# Epoch:40, Acc:94.87, Precision: 82.83, Recall: 86.73, F1: 84.74 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:41 completed, Total training's Loss: 2843967.0649414062, Spend: 1.354084837436676m
# Epoch:41, Acc:94.84, Precision: 82.23, Recall: 87.40, F1: 84.73 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:42 completed, Total training's Loss: 2842541.1416015625, Spend: 1.3467145800590514m
# Epoch:42, Acc:94.62, Precision: 81.95, Recall: 86.73, F1: 84.27 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:43 completed, Total training's Loss: 2839716.0805664062, Spend: 1.3518985033035278m
# Epoch:43, Acc:94.70, Precision: 81.27, Recall: 87.52, F1: 84.28 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:44 completed, Total training's Loss: 2836546.7309570312, Spend: 1.3499694426854452m
# Epoch:44, Acc:94.77, Precision: 81.96, Recall: 87.22, F1: 84.51 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:45 completed, Total training's Loss: 2837110.1499023438, Spend: 1.3574111660321553m
# Epoch:45, Acc:94.78, Precision: 82.16, Recall: 87.00, F1: 84.51 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:46 completed, Total training's Loss: 2834614.369140625, Spend: 1.3584115425745646m
# Epoch:46, Acc:94.68, Precision: 82.16, Recall: 86.43, F1: 84.24 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:47 completed, Total training's Loss: 2833303.4682617188, Spend: 1.3485105991363526m
# Epoch:47, Acc:94.79, Precision: 82.32, Recall: 86.70, F1: 84.45 on Valid_set, Spend:0.053 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:48 completed, Total training's Loss: 2833715.6284179688, Spend: 1.3579068581263225m
# Epoch:48, Acc:94.79, Precision: 82.32, Recall: 86.79, F1: 84.49 on Valid_set, Spend:0.054 minutes for evaluation
# --------------------------------------------------------------
# --------------------------------------------------------------
# Epoch:49 completed, Total training's Loss: 2830622.2451171875, Spend: 1.3448413252830504m
# Epoch:49, Acc:94.82, Precision: 82.48, Recall: 86.79, F1: 84.58 on Valid_set, Spend:0.055 minutes for evaluation
# --------------------------------------------------------------
# Epoch:49, Acc:96.30, Precision: 87.96, Recall: 90.77, F1: 89.34 on Test_set, Spend:0.052 minutes for evaluation
# --------------------------------------------------------------

# %%
# !python3 predict.py -I "Emotet malware attack taiwan"
# Out:
# 2023-04-10 06:00:53.498004: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 06:00:54.402819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loaded the pretrain  NER_BERT_CRF  model, epoch: 40 valid acc: 0.9487194048497927 valid f1: 0.8473520249221183
# /content/drive/MyDrive/ner_bert_crf_open_version/predict.py:515: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   valid_predicted = torch.masked_select(predicted_label_seq_ids, predict_mask)
# ----------------
# source sentence:  Emotet malware attack taiwan
# result sentence:  B-OffAct I-Tool O B-Area
